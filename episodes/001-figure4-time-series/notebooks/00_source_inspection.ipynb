# %% [markdown]
# # Source inspection
#
# Phase 1 placeholder. See `../docs/SOURCE_QUALITY.md` and `../sources/extracted/provenance.yaml`.

# %%
from pathlib import Path
root = Path('..').resolve()
print((root / 'docs' / 'SOURCE_QUALITY.md').read_text()[:1000])
